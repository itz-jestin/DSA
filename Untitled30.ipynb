# %% [markdown]
# <a href="https://colab.research.google.com/github/itz-jestin/DSA/blob/main/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def dutch_flag_prob(lst):
  low = 0
  mid = 0
  high=len(lst)-1
  a = 0
  count=1
  while mid<=high:
    count+=1
    print("count",count)
    if lst[mid]==0:
      a=lst[mid]
      lst[mid]=lst[low]
      lst[low]=a
      a=0
      low+=1
      mid+=1
      print(count,lst,"\n")
    elif lst[mid]==1:
      mid+=1
      print(count,lst,"\n")
    elif lst[mid]==2:
      a=lst[high]
      lst[high]=lst[mid]
      lst[mid]=a
      a=0
      high-=1
      print(count,lst,"\n")
  return lst
print("Final solution: ",dutch_flag_prob([1, 0, 2, 1, 1, 0]))
# Out:
# count 2
# 2 [1, 0, 2, 1, 1, 0]
#
# count 3
# 3 [0, 1, 2, 1, 1, 0]
#
# count 4
# 4 [0, 1, 0, 1, 1, 2]
#
# count 5
# 5 [0, 0, 1, 1, 1, 2]
#
# count 6
# 6 [0, 0, 1, 1, 1, 2]
#
# count 7
# 7 [0, 0, 1, 1, 1, 2]
#
# Final solution:  [0, 0, 1, 1, 1, 2]
